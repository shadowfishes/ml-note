# %% [markdown]
# # FM算法实现（向量化）

# %%
import numpy as np
import pandas as pd
import random

random.seed(0)
np.random.seed(0)

trainData = './data/diabetes_train.txt'   #请换为自己文件的路径
testData = './data/diabetes_test.txt'

def preprocessData(data):
    feature=np.array(data.iloc[:,:-1])   #取特征
    label=data.iloc[:,-1].map(lambda x: 1 if x==1 else -1) #取标签并转化为 +1，-1
    #将数组按行进行归一化
    zmax, zmin = feature.max(axis=0), feature.min(axis=0)
    feature = (feature - zmin) / (zmax - zmin)
    label=np.array(label)
    return feature,label

def sigmoid(data):
    return 1.0 / (1+np.exp(-data))

class FM:
    def __init__(self, k=8, learning_rate = 0.005):
        # 隐向量维数
        self.k = k
        # 学习率
        self.learning_rate = learning_rate

    def fit(self, data, label, iter):
        m, n = data.shape
        # 常数项系数
        self.w0 = 0.0
        #  一次项系数
        # self.w = np.random.normal(size=(n,1))
        self.w = np.zeros((n,1))
        # 二次项系数矩阵，即FM核心思想的隐向量系数矩阵
        # self.v = np.random.normal(size=(n,self.k))
        self.v = random.normalvariate(0, 0.2) * np.ones((n, self.k))

        for epoch in range(iter):
            # 采用SGD算法求解
            for index in range(m):
                feature = data[index].reshape(-1,1)
                inter_1 = np.sum(feature * self.v, axis=0,keepdims=True)
                inter_2 = np.sum((feature * feature) * (self.v * self.v),axis=0,keepdims=True)
                interaction = np.sum(inter_1 * inter_1 - inter_2, axis=1) / 2.0
                # 预测值
                pred = self.w0 + np.dot(feature.T,self.w) + interaction[0]
                # loss 部分梯度，即loss对sigmoid求导的结果方便后续计算
                loss = 1 - sigmoid(label[index] * pred[0,0])

                # 分别更新参数
                self.w0 = self.w0 + self.learning_rate * loss * label[index]
                self.w = self.w + self.learning_rate * loss  * label[index] * feature
                self.v = self.v + self.learning_rate * loss * label[index] * (feature * inter_1 -
                                                               (feature * feature) * self.v)
            print("第{}次迭代后的loss部分梯度为{}".format(epoch, loss))

    def predict(self,data):
        inter_1 = data.dot(self.v)
        inter_2 = (data * data).dot(self.v * self.v)
        interaction = np.sum(inter_1 * inter_1 - inter_2, axis=1) / 2.0

        # 预测值
        pred = self.w0 +data.dot(self.w) + interaction.reshape(-1,1)
        pred = np.where(pred>0.5, 1, -1)
        return pred

if __name__ == "__main__":
    train=pd.read_csv(trainData)
    test = pd.read_csv(testData)
    dataTrain, labelTrain = preprocessData(train)
    dataTest, labelTest = preprocessData(test)

    clf = FM(k=20)
    clf.fit(dataTrain, labelTrain,200)
    res = clf.predict(dataTest)
    prec = res == labelTest.reshape(-1,1)
    print("准确率：", np.sum(prec)/dataTest.shape[0])
# Out:
# 第0次迭代后的loss部分梯度为0.41668464877653133
# 第1次迭代后的loss部分梯度为0.3947650728939792
# 第2次迭代后的loss部分梯度为0.39614143824248094
# 第3次迭代后的loss部分梯度为0.4036920221903222
# 第4次迭代后的loss部分梯度为0.41314481820913174
# 第5次迭代后的loss部分梯度为0.42331589134482717
# 第6次迭代后的loss部分梯度为0.4337703555918372
# 第7次迭代后的loss部分梯度为0.4442493542185031
# 第8次迭代后的loss部分梯度为0.4545474290025685
# 第9次迭代后的loss部分梯度为0.46449822641563443
# 第10次迭代后的loss部分梯度为0.47397763260101977
# 第11次迭代后的loss部分梯度为0.4829031863916269
# 第12次迭代后的loss部分梯度为0.49122836822549876
# 第13次迭代后的loss部分梯度为0.49893466334881764
# 第14次迭代后的loss部分梯度为0.5060238330321158
# 第15次迭代后的loss部分梯度为0.5125115135247461
# 第16次迭代后的loss部分梯度为0.5184223447910306
# 第17次迭代后的loss部分梯度为0.5237864247634645
# 第18次迭代后的loss部分梯度为0.5286367883078127
# 第19次迭代后的loss部分梯度为0.5330076412918514
# 第20次迭代后的loss部分梯度为0.5369331423079942
# 第21次迭代后的loss部分梯度为0.5404465810361743
# 第22次迭代后的loss部分梯度为0.5435798446183919
# 第23次迭代后的loss部分梯度为0.5463630932654394
# 第24次迭代后的loss部分梯度为0.5488245871285184
# 第25次迭代后的loss部分梯度为0.5509906212267897
# 第26次迭代后的loss部分梯度为0.5528855359726854
# 第27次迭代后的loss部分梯度为0.5545317788741172
# 第28次迭代后的loss部分梯度为0.5559499991190924
# 第29次迭代后的loss部分梯度为0.5571591614721045
# 第30次迭代后的loss部分梯度为0.558176669570646
# 第31次迭代后的loss部分梯度为0.5590184915416762
# 第32次迭代后的loss部分梯度为0.559699283037882
# 第33次迭代后的loss部分梯度为0.5602325044575153
# 第34次迭代后的loss部分梯度为0.5606305303662817
# 第35次迭代后的loss部分梯度为0.560904750070687
# 第36次迭代后的loss部分梯度为0.561065658967999
# 第37次迭代后的loss部分梯度为0.5611229407740352
# 第38次迭代后的loss部分梯度为0.5610855410509684
# 第39次迭代后的loss部分梯度为0.5609617326593728
# 第40次迭代后的loss部分梯度为0.5607591738708674
# 第41次迭代后的loss部分梯度为0.5604849599232193
# 第42次迭代后的loss部分梯度为0.5601456687974424
# 第43次迭代后的loss部分梯度为0.5597474019609975
# 第44次迭代后的loss部分梯度为0.55929582076437
# 第45次迭代后的loss部分梯度为0.5587961791090783
# 第46次迭代后的loss部分梯度为0.5582533529304365
# 第47次迭代后的loss部分梯度为0.5576718669631973
# 第48次迭代后的loss部分梯度为0.5570559191861294
# 第49次迭代后的loss部分梯度为0.5564094032750427
# 第50次迭代后的loss部分梯度为0.555735929334282
# 第51次迭代后的loss部分梯度为0.5550388431248087
# 第52次迭代后的loss部分梯度为0.5543212439631096
# 第53次迭代后的loss部分梯度为0.5535860014287257
# 第54次迭代后的loss部分梯度为0.5528357709889442
# 第55次迭代后的loss部分梯度为0.5520730086261731
# 第56次迭代后的loss部分梯度为0.5512999845360811
# 第57次迭代后的loss部分梯度为0.5505187959517617
# 第58次迭代后的loss部分梯度为0.5497313791401894
# 第59次迭代后的loss部分梯度为0.5489395206112898
# 第60次迭代后的loss部分梯度为0.5481448675763106
# 第61次迭代后的loss部分梯度为0.5473489376902547
# 第62次迭代后的loss部分梯度为0.5465531281123774
# 第63次迭代后的loss部分梯度为0.5457587239187282
# 第64次迭代后的loss部分梯度为0.5449669059010865
# 第65次迭代后的loss部分梯度为0.544178757787118
# 第66次迭代后的loss部分梯度为0.5433952729169844
# 第67次迭代后的loss部分梯度为0.5426173604118707
# 第68次迭代后的loss部分梯度为0.5418458508697508
# 第69次迭代后的loss部分梯度为0.5410815016233608
# 第70次迭代后的loss部分梯度为0.5403250015945429
# 第71次迭代后的loss部分梯度为0.5395769757780966
# 第72次迭代后的loss部分梯度为0.5388379893868798
# 第73次迭代后的loss部分梯度为0.5381085516883468
# 第74次迭代后的loss部分梯度为0.5373891195608833
# 第75次迭代后的loss部分梯度为0.5366801007964155
# 第76次迭代后的loss部分梯度为0.5359818571737347
# 第77次迭代后的loss部分梯度为0.5352947073249356
# 第78次迭代后的loss部分梯度为0.534618929415319
# 第79次迭代后的loss部分梯度为0.5339547636551438
# 第80次迭代后的loss部分梯度为0.533302414659582
# 第81次迭代后的loss部分梯度为0.5326620536715214
# 第82次迭代后的loss部分梯度为0.5320338206600361
# 第83次迭代后的loss部分梯度为0.5314178263057976
# 第84次迭代后的loss部分梯度为0.530814153883223
# 第85次迭代后的loss部分梯度为0.5302228610478503
# 第86次迭代后的loss部分梯度为0.5296439815362481
# 第87次迭代后的loss部分梯度为0.5290775267846739
# 第88次迭代后的loss部分梯度为0.5285234874718773
# 第89次迭代后的loss部分梯度为0.5279818349905616
# 第90次迭代后的loss部分梯度为0.5274525228513831
# 第91次迭代后的loss部分梯度为0.526935488022797
# 第92次迭代后的loss部分梯度为0.5264306522095717
# 第93次迭代后的loss部分梯度为0.5259379230724154
# 第94次迭代后的loss部分梯度为0.5254571953908124
# 第95次迭代后的loss部分梯度为0.5249883521709864
# 第96次迭代后的loss部分梯度为0.524531265700616
# 第97次迭代后的loss部分梯度为0.5240857985518836
# 第98次迭代后的loss部分梯度为0.5236518045342546
# 第99次迭代后的loss部分梯度为0.5232291295983733
# 第100次迭代后的loss部分梯度为0.5228176126923385
# 第101次迭代后的loss部分梯度为0.5224170865717301
# 第102次迭代后的loss部分梯度为0.5220273785645707
# 第103次迭代后的loss部分梯度为0.5216483112925714
# 第104次迭代后的loss部分梯度为0.5212797033499308
# 第105次迭代后的loss部分梯度为0.5209213699409895
# 第106次迭代后的loss部分梯度为0.5205731234780842
# 第107次迭代后的loss部分梯度为0.5202347741409243
# 第108次迭代后的loss部分梯度为0.519906130398877
# 第109次迭代后的loss部分梯度为0.5195869994975213
# 第110次迭代后的loss部分梯度为0.5192771879108486
# 第111次迭代后的loss部分梯度为0.5189765017605437
# 第112次迭代后的loss部分梯度为0.5186847472036901
# 第113次迭代后的loss部分梯度为0.5184017307903327
# 第114次迭代后的loss部分梯度为0.5181272597922658
# 第115次迭代后的loss部分梯度为0.5178611425044303
# 第116次迭代后的loss部分梯度为0.5176031885202743
# 第117次迭代后的loss部分梯度为0.5173532089824049
# 第118次迭代后的loss部分梯度为0.5171110168098682
# 第119次迭代后的loss部分梯度为0.5168764269033221
# 第120次迭代后的loss部分梯度为0.5166492563293557
# 第121次迭代后的loss部分梯度为0.5164293244851892
# 第122次迭代后的loss部分梯度为0.516216453244928
# 第123次迭代后的loss部分梯度为0.5160104670885131
# 第124次迭代后的loss部分梯度为0.5158111932144771
# 第125次迭代后的loss部分梯度为0.5156184616375696
# 第126次迭代后的loss部分梯度为0.515432105272277
# 第127次迭代后的loss部分梯度为0.5152519600031936
# 第128次迭代后的loss部分梯度为0.5150778647432283
# 第129次迭代后的loss部分梯度为0.5149096614804696
# 第130次迭代后的loss部分梯度为0.514747195314635
# 第131次迭代后的loss部分梯度为0.5145903144838501
# 第132次迭代后的loss部分梯度为0.5144388703825592
# 第133次迭代后的loss部分梯度为0.5142927175712864
# 第134次迭代后的loss部分梯度为0.5141517137789196
# 第135次迭代后的loss部分梯度为0.5140157198981861
# 第136次迭代后的loss部分梯度为0.5138845999749069
# 第137次迭代后的loss部分梯度为0.5137582211916069
# 第138次迭代后的loss部分梯度为0.5136364538460456
# 第139次迭代后的loss部分梯度为0.5135191713251209
# 第140次迭代后的loss部分梯度为0.5134062500746576
# 第141次迭代后的loss部分梯度为0.5132975695655115
# 第142次迭代后的loss部分梯度为0.5131930122563877
# 第143次迭代后的loss部分梯度为0.5130924635537535
# 第144次迭代后的loss部分梯度为0.5129958117692353
# 第145次迭代后的loss部分梯度为0.5129029480747602
# 第146次迭代后的loss部分梯度为0.5128137664558301
# 第147次迭代后的loss部分梯度为0.5127281636631358
# 第148次迭代后的loss部分梯度为0.5126460391628157
# 第149次迭代后的loss部分梯度为0.512567295085586
# 第150次迭代后的loss部分梯度为0.51249183617496
# 第151次迭代后的loss部分梯度为0.5124195697347458
# 第152次迭代后的loss部分梯度为0.5123504055760535
# 第153次迭代后的loss部分梯度为0.5122842559639154
# 第154次迭代后的loss部分梯度为0.5122210355637211
# 第155次迭代后的loss部分梯度为0.5121606613875924
# 第156次迭代后的loss部分梯度为0.5121030527408296
# 第157次迭代后的loss部分梯度为0.5120481311685199
# 第158次迭代后的loss部分梯度为0.511995820402463
# 第159次迭代后的loss部分梯度为0.5119460463084367
# 第160次迭代后的loss部分梯度为0.5118987368339625
# 第161次迭代后的loss部分梯度为0.5118538219565754
# 第162次迭代后的loss部分梯度为0.5118112336327085
# 第163次迭代后的loss部分梯度为0.5117709057472413
# 第164次迭代后的loss部分梯度为0.5117327740637454
# 第165次迭代后的loss部分梯度为0.5116967761754938
# 第166次迭代后的loss部分梯度为0.5116628514572592
# 第167次迭代后的loss部分梯度为0.5116309410179389
# 第168次迭代后的loss部分梯度为0.5116009876540211
# 第169次迭代后的loss部分梯度为0.5115729358039403
# 第170次迭代后的loss部分梯度为0.5115467315033326
# 第171次迭代后的loss部分梯度为0.511522322341159
# 第172次迭代后的loss部分梯度为0.5114996574167985
# 第173次迭代后的loss部分梯度为0.5114786872980277
# 第174次迭代后的loss部分梯度为0.5114593639799557
# 第175次迭代后的loss部分梯度为0.5114416408448716
# 第176次迭代后的loss部分梯度为0.5114254726230474
# 第177次迭代后的loss部分梯度为0.5114108153544459
# 第178次迭代后的loss部分梯度为0.5113976263513662
# 第179次迭代后的loss部分梯度为0.5113858641620183
# 第180次迭代后的loss部分梯度为0.51137548853498
# 第181次迭代后的loss部分梯度为0.5113664603845801
# 第182次迭代后的loss部分梯度为0.5113587417571631
# 第183次迭代后的loss部分梯度为0.5113522957982317
# 第184次迭代后的loss部分梯度为0.5113470867204618
# 第185次迭代后的loss部分梯度为0.5113430797725582
# 第186次迭代后的loss部分梯度为0.5113402412089711
# 第187次迭代后的loss部分梯度为0.5113385382604134
# 第188次迭代后的loss部分梯度为0.5113379391052009
# 第189次迭代后的loss部分梯度为0.5113384128413898
# 第190次迭代后的loss部分梯度为0.5113399294596755
# 第191次迭代后的loss部分梯度为0.5113424598170697
# 第192次迭代后的loss部分梯度为0.5113459756113233
# 第193次迭代后的loss部分梯度为0.5113504493560612
# 第194次迭代后的loss部分梯度为0.5113558543566454
# 第195次迭代后的loss部分梯度为0.511362164686731
# 第196次迭代后的loss部分梯度为0.5113693551654953
# 第197次迭代后的loss部分梯度为0.5113774013355412
# 第198次迭代后的loss部分梯度为0.5113862794414336
# 第199次迭代后的loss部分梯度为0.5113959664088753
# 准确率： 0.8052434456928839
